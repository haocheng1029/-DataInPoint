# %%
import pandas as pd
xlsx_file = "gapminder.xlsx"
gapminder = pd.read_excel(xlsx_file)
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
gapminder['country_tab'] =  gapminder['country'].apply(lambda x: x[:3])
gapminder
# Out:
#           country continent  year  lifeExp       pop    gdpPercap country_tab
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314         Afg
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030         Afg
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710         Afg
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138         Afg
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106         Afg
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360         Afg
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439         Afg
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945         Afg
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395         Afg
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351         Afg
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055         Afg
# ...

# %%
gapminder[gapminder['year'] == 2007] [['pop']].sum()
# Out:
# pop    6251013179
# dtype: int64

# %%
gapminder[gapminder['year'] == 2007][['lifeExp','gdpPercap']].mean()
# Out:
# lifeExp         67.007423
# gdpPercap    11680.071820
# dtype: float64

# %%
gapminder[gapminder['year'] == 2007].groupby(by = 'continent')['pop'].sum()
# Out:
# continent
# Africa       929539692
# Americas     898871184
# Asia        3811953827
# Europe       586098529
# Oceania       24549947
# Name: pop, dtype: int64

# %%
gapminder[gapminder['year'] == 2002 ].groupby(by = 'continent')['lifeExp','gdpPercap'].mean()
# Out:
#              lifeExp     gdpPercap
# continent
# Africa     53.325231   2599.385159
# Americas   72.422040   9287.677107
# Asia       69.233879  10174.090397
# Europe     76.700600  21711.732422
# Oceania    79.740000  26938.778040

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gapminder_twn = gapminder[gapminder['country'] == 'Taiwan']
gapminder_twn[['year','pop']].plot(kind = 'line', x = 'year', y = 'pop', title = 'Pop vs. Year in Taiwan', legend = False)
plt.show()

# %%
gapminder_northasia = gapminder.loc[gapminder['country'].isin(['China', 'Japan', 'Korea, Rep.', 'Taiwan'])]
gapminder_northasia_pivot = gapminder_northasia.pivot_table(values = 'lifeExp', columns = 'country', index = 'year')
gapminder_northasia_pivot.plot(title = 'Life Expectancies in NorthAsia')
plt.show()

# %%
gapminder_2007 = gapminder[gapminder['year'] == 2007 ]
gapminder_2007[['pop', 'lifeExp', 'gdpPercap']].hist(bins = 15 )
plt.show()

# %%
gapminder_2007[['gdpPercap']].plot(kind = 'hist', title = 'GDP Per Capita in 2007', legend = False, bins = 15)
plt.show()

# %%
gapminder_continent_pivot = gapminder_2007.pivot_table(values= 'gdpPercap', columns = 'continent', index= 'country')
gapminder_continent_pivot.plot(kind = 'hist', alpha=0.5, bins = 20, title = 'GDP Per Capita by Continent')
plt.show()

# %%
gapminder_2007.plot(kind= 'hexbin', x= 'gdpPercap', y= 'lifeExp', gridsize= 30, title = 'Wealth vs. Health in 2007')
plt.show()
